# %%
import random
import numpy as np
import gymnasium as gym
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque
import yfinance as yf
import pandas as pd

# --- Load Historical Data ---
def load_stock_data(tickers, start="2020-01-01", end="2024-12-31"):
    data = yf.download(tickers, start=start, end=end)["Close"]
    #returns = data.pct_change().dropna()
    return data

# --- Custom Gymnasium Environment ---
class StockEnv(gym.Env):
    def __init__(self, stocks, actions, returns_df, window_size=45):
        super(StockEnv, self).__init__()
        self.stocks = stocks
        self.actions = actions
        self.returns_df = returns_df
        self.dates = returns_df.index.tolist()
        self.window_size = window_size
        self.action_space = gym.spaces.Discrete(len(stocks) * len(actions))
        self.observation_space = gym.spaces.Box(
            low=-1, high=1, shape=(window_size, len(stocks)), dtype=np.float32
        )
        self.reset()

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.start_idx = random.randint(0, len(self.returns_df) - 2 * self.window_size)
        self.current_step = self.start_idx + self.window_size
        self.episode_reward = 0
        self.done = False
        return self._get_observation(), {}

    def _get_observation(self):
        window = self.returns_df.iloc[self.current_step - self.window_size:self.current_step].values
        return window.astype(np.float32)

    def step(self, action_idx):
        stock_idx = action_idx // len(self.actions)
        print("action_idx", action_idx)
        print("len(self.actions)", len(self.actions))
        print("stock_idx", stock_idx)
        action_type_idx = action_idx % len(self.actions)
        print("action_type_idx", action_type_idx)
        action_type = self.actions[action_type_idx]
        print("action_type", action_type)

        base_return = self.returns_df.iloc[self.current_step, stock_idx]
        print("base_return", base_return)

        # Define risk-adjusted reward multiplier
        reward_multiplier = {
            "Buy more": 0.3,
            "Buy mid": 0.5,
            "Buy less": 1,
            "Sell more": 0.3,
            "Sell mid": 0.5,
            "Sell less": 1,
            "Keep": 1
        }[action_type]

        reward = base_return * reward_multiplier
        print("reward", reward)
        self.episode_reward += reward
        print("episode_reward", self.episode_reward)

        self.current_step += 1
        print("current_step", self.current_step)
        terminated = (self.current_step - self.start_idx) >= 2 * self.window_size
        print("terminated", terminated)
        truncated = False

        return self._get_observation(), reward, terminated, truncated, {}

# --- Linear-based Q-Network ---
class LinearDQN(nn.Module):
    def __init__(self, input_dim, seq_len, output_dim):
        super(LinearDQN, self).__init__()
        self.fc = nn.Sequential(
            nn.Flatten(),
            nn.Linear(seq_len * input_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, output_dim)
        )

    def forward(self, x):
        return self.fc(x)

# --- Hyperparameters ---
stocks = ["AAPL", "MSFT", "GOOGL", "AMZN"]
actions = ["Buy more", "Buy mid", "Buy less", "Sell more", "Sell mid", "Sell less", "Keep"]
returns_df = load_stock_data(stocks)

env = StockEnv(stocks, actions, returns_df, window_size=45)

epsilon = 1.0
epsilon_min = 0.01
epsilon_decay = 0.995
gamma = 0.99
lr = 0.001
batch_size = 32
memory = deque(maxlen=2000)

input_dim = len(stocks)
seq_len = env.window_size
output_dim = env.action_space.n

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = LinearDQN(input_dim, seq_len, output_dim).to(device)
optimizer = optim.Adam(model.parameters(), lr=lr)

# --- Training Loop ---
def train_dqn(episodes):
    global epsilon
    for e in range(episodes):
        state, _ = env.reset()
        state = torch.FloatTensor(state).unsqueeze(0).to(device)  # [1, seq_len, input_dim]
        total_reward = 0

        for t in range(env.window_size):
            if random.random() <= epsilon:
                action = env.action_space.sample()
            else:
                with torch.no_grad():
                    q_values = model(state)
                    action = q_values.argmax().item()

            next_state, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            total_reward += reward

            next_state_tensor = torch.FloatTensor(next_state).unsqueeze(0).to(device)
            memory.append((state, action, reward, next_state_tensor, done))
            state = next_state_tensor

            if len(memory) >= batch_size:
                minibatch = random.sample(memory, batch_size)
                states, actions_, rewards_, next_states, dones = zip(*minibatch)

                states = torch.cat(states, dim=0)  # [B, seq_len, input_dim]
                next_states = torch.cat(next_states, dim=0)
                actions_ = torch.LongTensor(actions_).unsqueeze(1).to(device)
                rewards_ = torch.FloatTensor(rewards_).unsqueeze(1).to(device)

                current_q = model(states).gather(1, actions_)
                next_q = model(next_states).max(1)[0].unsqueeze(1).detach()
                target_q = rewards_ + (gamma * next_q)

                loss = nn.MSELoss()(current_q, target_q)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

            if done:
                break

        if epsilon > epsilon_min:
            epsilon *= epsilon_decay

        print(f"Episode {e+1}/{episodes}, Total Excess Return: {total_reward:.4f}, Epsilon: {epsilon:.2f}")

train_dqn(100)
# Out:
# [*********************100%***********************]  4 of 4 completed
# 串流輸出內容已截斷至最後 5000 行。
# stock_idx 2
# action_type_idx 3
# action_type Sell more
# base_return 97.39436340332031
# reward 29.21830902099609
# episode_reward 6230.272504425049
# current_step 699
# terminated False
# action_idx 17
# len(self.actions) 7
# stock_idx 2
# action_type_idx 3
# action_type Sell more
# base_return 96.71759033203125
# reward 29.015277099609374
# episode_reward 6259.287781524658
# current_step 700
# terminated False
# action_idx 23
# len(self.actions) 7
# stock_idx 3
# action_type_idx 2
# action_type Buy less
# base_return 221.03762817382812
# reward 221.03762817382812
# episode_reward 6480.3254096984865
# current_step 701
# terminated False
# action_idx 6
# len(self.actions) 7
# stock_idx 0
# action_type_idx 6
# action_type Keep
# base_return 140.92767333984375
# reward 140.92767333984375
# episode_reward 6621.25308303833
# current_step 702
# terminated True
# Episode 89/100, Total Excess Return: 6621.2531, Epsilon: 0.64
# action_idx 2
# len(self.actions) 7
# stock_idx 0
# action_type_idx 2
# action_type Buy less
# base_return 142.6422882080078
# reward 142.6422882080078
# episode_reward 142.6422882080078
# current_step 743
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 252.2659149169922
# reward 252.2659149169922
# episode_reward 394.908203125
# current_step 744
# terminated False
# action_idx 14
# len(self.actions) 7
# stock_idx 2
# action_type_idx 0
# action_type Buy more
# base_return 94.61764526367188
# reward 28.38529357910156
# episode_reward 423.2934967041016
# current_step 745
# terminated False
# action_idx 17
# len(self.actions) 7
# stock_idx 2
# action_type_idx 3
# action_type Sell more
# base_return 90.42767333984375
# reward 27.128302001953124
# episode_reward 450.4217987060547
# current_step 746
# terminated False
# action_idx 3
# len(self.actions) 7
# stock_idx 0
# action_type_idx 3
# action_type Sell more
# base_return 132.78988647460938
# reward 39.83696594238281
# episode_reward 490.2587646484375
# current_step 747
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 236.09426879882812
# reward 236.09426879882812
# episode_reward 726.3530334472656
# current_step 748
# terminated False
# action_idx 2
# len(self.actions) 7
# stock_idx 0
# action_type_idx 2
# action_type Buy less
# base_return 130.608154296875
# reward 130.608154296875
# episode_reward 856.9611877441406
# current_step 749
# terminated False
# action_idx 2
# len(self.actions) 7
# stock_idx 0
# action_type_idx 2
# action_type Buy less
# base_return 133.71788024902344
# reward 133.71788024902344
# episode_reward 990.679067993164
# current_step 750
# terminated False
# action_idx 16
# len(self.actions) 7
# stock_idx 2
# action_type_idx 2
# action_type Buy less
# base_return 87.34242248535156
# reward 87.34242248535156
# episode_reward 1078.0214904785157
# current_step 751
# terminated False
# action_idx 19
# len(self.actions) 7
# stock_idx 2
# action_type_idx 5
# action_type Sell less
# base_return 88.80542755126953
# reward 88.80542755126953
# episode_reward 1166.8269180297852
# current_step 752
# terminated False
# action_idx 15
# len(self.actions) 7
# stock_idx 2
# action_type_idx 1
# action_type Buy mid
# base_return 86.97418212890625
# reward 43.487091064453125
# episode_reward 1210.3140090942384
# current_step 753
# terminated False
# action_idx 25
# len(self.actions) 7
# stock_idx 3
# action_type_idx 4
# action_type Sell mid
# base_return 230.28150939941406
# reward 115.14075469970703
# episode_reward 1325.4547637939454
# current_step 754
# terminated False
# action_idx 18
# len(self.actions) 7
# stock_idx 2
# action_type_idx 4
# action_type Sell mid
# base_return 88.02912902832031
# reward 44.014564514160156
# episode_reward 1369.4693283081056
# current_step 755
# terminated False
# action_idx 4
# len(self.actions) 7
# stock_idx 0
# action_type_idx 4
# action_type Sell mid
# base_return 128.2684326171875
# reward 64.13421630859375
# episode_reward 1433.6035446166993
# current_step 756
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 235.2400360107422
# reward 235.2400360107422
# episode_reward 1668.8435806274415
# current_step 757
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 224.94989013671875
# reward 224.94989013671875
# episode_reward 1893.7934707641602
# current_step 758
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 218.28286743164062
# reward 218.28286743164062
# episode_reward 2112.076338195801
# current_step 759
# terminated False
# action_idx 23
# len(self.actions) 7
# stock_idx 3
# action_type_idx 2
# action_type Buy less
# base_return 220.85540771484375
# reward 220.85540771484375
# episode_reward 2332.9317459106446
# current_step 760
# terminated False
# action_idx 23
# len(self.actions) 7
# stock_idx 3
# action_type_idx 2
# action_type Buy less
# base_return 223.00572204589844
# reward 223.00572204589844
# episode_reward 2555.937467956543
# current_step 761
# terminated False
# action_idx 17
# len(self.actions) 7
# stock_idx 2
# action_type_idx 3
# action_type Sell more
# base_return 87.99928283691406
# reward 26.39978485107422
# episode_reward 2582.3372528076175
# current_step 762
# terminated False
# action_idx 9
# len(self.actions) 7
# stock_idx 1
# action_type_idx 2
# action_type Buy less
# base_return 95.08999633789062
# reward 95.08999633789062
# episode_reward 2677.427249145508
# current_step 763
# terminated False
# action_idx 23
# len(self.actions) 7
# stock_idx 3
# action_type_idx 2
# action_type Buy less
# base_return 234.18939208984375
# reward 234.18939208984375
# episode_reward 2911.616641235352
# current_step 764
# terminated False
# action_idx 14
# len(self.actions) 7
# stock_idx 2
# action_type_idx 0
# action_type Buy more
# base_return 91.68167877197266
# reward 27.504503631591795
# episode_reward 2939.1211448669437
# current_step 765
# terminated False
# action_idx 12
# len(self.actions) 7
# stock_idx 1
# action_type_idx 5
# action_type Sell less
# base_return 96.05000305175781
# reward 96.05000305175781
# episode_reward 3035.1711479187015
# current_step 766
# terminated False
# action_idx 23
# len(self.actions) 7
# stock_idx 3
# action_type_idx 2
# action_type Buy less
# base_return 231.53831481933594
# reward 231.53831481933594
# episode_reward 3266.7094627380375
# current_step 767
# terminated False
# action_idx 22
# len(self.actions) 7
# stock_idx 3
# action_type_idx 1
# action_type Buy mid
# base_return 227.72860717773438
# reward 113.86430358886719
# episode_reward 3380.5737663269047
# current_step 768
# terminated False
# action_idx 23
# len(self.actions) 7
# stock_idx 3
# action_type_idx 2
# action_type Buy less
# base_return 235.86843872070312
# reward 235.86843872070312
# episode_reward 3616.442205047608
# current_step 769
# terminated False
# action_idx 11
# len(self.actions) 7
# stock_idx 1
# action_type_idx 4
# action_type Sell mid
# base_return 97.5199966430664
# reward 48.7599983215332
# episode_reward 3665.202203369141
# current_step 770
# terminated False
# action_idx 17
# len(self.actions) 7
# stock_idx 2
# action_type_idx 3
# action_type Sell more
# base_return 97.23511505126953
# reward 29.170534515380858
# episode_reward 3694.372737884522
# current_step 771
# terminated False
# action_idx 23
# len(self.actions) 7
# stock_idx 3
# action_type_idx 2
# action_type Buy less
# base_return 236.25135803222656
# reward 236.25135803222656
# episode_reward 3930.6240959167485
# current_step 772
# terminated False
# action_idx 16
# len(self.actions) 7
# stock_idx 2
# action_type_idx 2
# action_type Buy less
# base_return 97.05596923828125
# reward 97.05596923828125
# episode_reward 4027.6800651550298
# current_step 773
# terminated False
# action_idx 23
# len(self.actions) 7
# stock_idx 3
# action_type_idx 2
# action_type Buy less
# base_return 243.66458129882812
# reward 243.66458129882812
# episode_reward 4271.344646453857
# current_step 774
# terminated False
# action_idx 2
# len(self.actions) 7
# stock_idx 0
# action_type_idx 2
# action_type Buy less
# base_return 141.17132568359375
# reward 141.17132568359375
# episode_reward 4412.515972137451
# current_step 775
# terminated False
# action_idx 23
# len(self.actions) 7
# stock_idx 3
# action_type_idx 2
# action_type Buy less
# base_return 243.32093811035156
# reward 243.32093811035156
# episode_reward 4655.836910247803
# current_step 776
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 248.1714324951172
# reward 248.1714324951172
# episode_reward 4904.00834274292
# current_step 777
# terminated False
# action_idx 16
# len(self.actions) 7
# stock_idx 2
# action_type_idx 2
# action_type Buy less
# base_return 107.22734832763672
# reward 107.22734832763672
# episode_reward 5011.235691070557
# current_step 778
# terminated False
# action_idx 15
# len(self.actions) 7
# stock_idx 2
# action_type_idx 1
# action_type Buy mid
# base_return 104.28143310546875
# reward 52.140716552734375
# episode_reward 5063.376407623291
# current_step 779
# terminated False
# action_idx 19
# len(self.actions) 7
# stock_idx 2
# action_type_idx 5
# action_type Sell less
# base_return 102.41038513183594
# reward 102.41038513183594
# episode_reward 5165.786792755127
# current_step 780
# terminated False
# action_idx 21
# len(self.actions) 7
# stock_idx 3
# action_type_idx 0
# action_type Buy more
# base_return 262.7131652832031
# reward 78.81394958496094
# episode_reward 5244.600742340088
# current_step 781
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 261.8982238769531
# reward 261.8982238769531
# episode_reward 5506.498966217041
# current_step 782
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 258.8445129394531
# reward 258.8445129394531
# episode_reward 5765.343479156494
# current_step 783
# terminated False
# action_idx 5
# len(self.actions) 7
# stock_idx 0
# action_type_idx 5
# action_type Sell less
# base_return 149.3065185546875
# reward 149.3065185546875
# episode_reward 5914.649997711182
# current_step 784
# terminated False
# action_idx 7
# len(self.actions) 7
# stock_idx 1
# action_type_idx 0
# action_type Buy more
# base_return 99.54000091552734
# reward 29.8620002746582
# episode_reward 5944.51199798584
# current_step 785
# terminated False
# action_idx 26
# len(self.actions) 7
# stock_idx 3
# action_type_idx 5
# action_type Sell less
# base_return 267.23968505859375
# reward 267.23968505859375
# episode_reward 6211.751683044434
# current_step 786
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 265.1036682128906
# reward 265.1036682128906
# episode_reward 6476.855351257324
# current_step 787
# terminated True
# Episode 90/100, Total Excess Return: 6476.8554, Epsilon: 0.64
# action_idx 12
# len(self.actions) 7
# stock_idx 1
# action_type_idx 5
# action_type Sell less
# base_return 157.9355010986328
# reward 157.9355010986328
# episode_reward 157.9355010986328
# current_step 530
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 296.266845703125
# reward 296.266845703125
# episode_reward 454.2023468017578
# current_step 531
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 302.7357482910156
# reward 302.7357482910156
# episode_reward 756.9380950927734
# current_step 532
# terminated False
# action_idx 9
# len(self.actions) 7
# stock_idx 1
# action_type_idx 2
# action_type Buy less
# base_return 159.0034942626953
# reward 159.0034942626953
# episode_reward 915.9415893554688
# current_step 533
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 287.006103515625
# reward 287.006103515625
# episode_reward 1202.9476928710938
# current_step 534
# terminated False
# action_idx 13
# len(self.actions) 7
# stock_idx 1
# action_type_idx 6
# action_type Keep
# base_return 155.16700744628906
# reward 155.16700744628906
# episode_reward 1358.1147003173828
# current_step 535
# terminated False
# action_idx 5
# len(self.actions) 7
# stock_idx 0
# action_type_idx 5
# action_type Sell less
# base_return 169.8121795654297
# reward 169.8121795654297
# episode_reward 1527.9268798828125
# current_step 536
# terminated False
# action_idx 8
# len(self.actions) 7
# stock_idx 1
# action_type_idx 1
# action_type Buy mid
# base_return 158.10049438476562
# reward 79.05024719238281
# episode_reward 1606.9771270751953
# current_step 537
# terminated False
# action_idx 17
# len(self.actions) 7
# stock_idx 2
# action_type_idx 3
# action_type Sell more
# base_return 131.90834045410156
# reward 39.57250213623047
# episode_reward 1646.5496292114258
# current_step 538
# terminated False
# action_idx 9
# len(self.actions) 7
# stock_idx 1
# action_type_idx 2
# action_type Buy less
# base_return 152.60150146484375
# reward 152.60150146484375
# episode_reward 1799.1511306762695
# current_step 539
# terminated False
# action_idx 15
# len(self.actions) 7
# stock_idx 2
# action_type_idx 1
# action_type Buy mid
# base_return 129.19581604003906
# reward 64.59790802001953
# episode_reward 1863.749038696289
# current_step 540
# terminated False
# action_idx 11
# len(self.actions) 7
# stock_idx 1
# action_type_idx 4
# action_type Sell mid
# base_return 144.82699584960938
# reward 72.41349792480469
# episode_reward 1936.1625366210938
# current_step 541
# terminated False
# action_idx 11
# len(self.actions) 7
# stock_idx 1
# action_type_idx 4
# action_type Sell mid
# base_return 151.35800170898438
# reward 75.67900085449219
# episode_reward 2011.841537475586
# current_step 542
# terminated False
# action_idx 19
# len(self.actions) 7
# stock_idx 2
# action_type_idx 5
# action_type Sell less
# base_return 133.81973266601562
# reward 133.81973266601562
# episode_reward 2145.6612701416016
# current_step 543
# terminated False
# action_idx 23
# len(self.actions) 7
# stock_idx 3
# action_type_idx 2
# action_type Buy less
# base_return 291.25494384765625
# reward 291.25494384765625
# episode_reward 2436.916213989258
# current_step 544
# terminated False
# action_idx 23
# len(self.actions) 7
# stock_idx 3
# action_type_idx 2
# action_type Buy less
# base_return 287.5118103027344
# reward 287.5118103027344
# episode_reward 2724.428024291992
# current_step 545
# terminated False
# action_idx 23
# len(self.actions) 7
# stock_idx 3
# action_type_idx 2
# action_type Buy less
# base_return 292.6195983886719
# reward 292.6195983886719
# episode_reward 3017.047622680664
# current_step 546
# terminated False
# action_idx 2
# len(self.actions) 7
# stock_idx 0
# action_type_idx 2
# action_type Buy less
# base_return 163.3651885986328
# reward 163.3651885986328
# episode_reward 3180.412811279297
# current_step 547
# terminated False
# action_idx 18
# len(self.actions) 7
# stock_idx 2
# action_type_idx 4
# action_type Sell mid
# base_return 131.2788543701172
# reward 65.6394271850586
# episode_reward 3246.0522384643555
# current_step 548
# terminated False
# action_idx 1
# len(self.actions) 7
# stock_idx 0
# action_type_idx 1
# action_type Buy mid
# base_return 156.5546417236328
# reward 78.2773208618164
# episode_reward 3324.329559326172
# current_step 549
# terminated False
# action_idx 4
# len(self.actions) 7
# stock_idx 0
# action_type_idx 4
# action_type Sell mid
# base_return 154.7266845703125
# reward 77.36334228515625
# episode_reward 3401.692901611328
# current_step 550
# terminated False
# action_idx 22
# len(self.actions) 7
# stock_idx 3
# action_type_idx 1
# action_type Buy mid
# base_return 281.2243957519531
# reward 140.61219787597656
# episode_reward 3542.3050994873047
# current_step 551
# terminated False
# action_idx 19
# len(self.actions) 7
# stock_idx 2
# action_type_idx 5
# action_type Sell less
# base_return 131.7993927001953
# reward 131.7993927001953
# episode_reward 3674.1044921875
# current_step 552
# terminated False
# action_idx 23
# len(self.actions) 7
# stock_idx 3
# action_type_idx 2
# action_type Buy less
# base_return 273.00701904296875
# reward 273.00701904296875
# episode_reward 3947.1115112304688
# current_step 553
# terminated False
# action_idx 0
# len(self.actions) 7
# stock_idx 0
# action_type_idx 0
# action_type Buy more
# base_return 148.02423095703125
# reward 44.40726928710937
# episode_reward 3991.5187805175783
# current_step 554
# terminated False
# action_idx 21
# len(self.actions) 7
# stock_idx 3
# action_type_idx 0
# action_type Buy more
# base_return 279.9085388183594
# reward 83.97256164550781
# episode_reward 4075.4913421630863
# current_step 555
# terminated False
# action_idx 13
# len(self.actions) 7
# stock_idx 1
# action_type_idx 6
# action_type Keep
# base_return 153.10400390625
# reward 153.10400390625
# episode_reward 4228.595346069336
# current_step 556
# terminated False
# action_idx 13
# len(self.actions) 7
# stock_idx 1
# action_type_idx 6
# action_type Keep
# base_return 157.23899841308594
# reward 157.23899841308594
# episode_reward 4385.834344482422
# current_step 557
# terminated False
# action_idx 20
# len(self.actions) 7
# stock_idx 2
# action_type_idx 6
# action_type Keep
# base_return 135.47779846191406
# reward 135.47779846191406
# episode_reward 4521.312142944336
# current_step 558
# terminated False
# action_idx 23
# len(self.actions) 7
# stock_idx 3
# action_type_idx 2
# action_type Buy less
# base_return 291.6156311035156
# reward 291.6156311035156
# episode_reward 4812.927774047852
# current_step 559
# terminated False
# action_idx 18
# len(self.actions) 7
# stock_idx 2
# action_type_idx 4
# action_type Sell mid
# base_return 139.20248413085938
# reward 69.60124206542969
# episode_reward 4882.529016113282
# current_step 560
# terminated False
# action_idx 9
# len(self.actions) 7
# stock_idx 1
# action_type_idx 2
# action_type Buy less
# base_return 163.4080047607422
# reward 163.4080047607422
# episode_reward 5045.937020874024
# current_step 561
# terminated False
# action_idx 6
# len(self.actions) 7
# stock_idx 0
# action_type_idx 6
# action_type Keep
# base_return 171.07009887695312
# reward 171.07009887695312
# episode_reward 5217.007119750977
# current_step 562
# terminated False
# action_idx 0
# len(self.actions) 7
# stock_idx 0
# action_type_idx 0
# action_type Buy more
# base_return 171.70887756347656
# reward 51.51266326904297
# episode_reward 5268.5197830200195
# current_step 563
# terminated False
# action_idx 7
# len(self.actions) 7
# stock_idx 1
# action_type_idx 0
# action_type Buy more
# base_return 168.99049377441406
# reward 50.697148132324216
# episode_reward 5319.216931152344
# current_step 564
# terminated False
# action_idx 21
# len(self.actions) 7
# stock_idx 3
# action_type_idx 0
# action_type Buy more
# base_return 307.4558410644531
# reward 92.23675231933593
# episode_reward 5411.45368347168
# current_step 565
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 305.9449768066406
# reward 305.9449768066406
# episode_reward 5717.398660278321
# current_step 566
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 300.5348815917969
# reward 300.5348815917969
# episode_reward 6017.933541870118
# current_step 567
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 301.61688232421875
# reward 301.61688232421875
# episode_reward 6319.550424194336
# current_step 568
# terminated False
# action_idx 16
# len(self.actions) 7
# stock_idx 2
# action_type_idx 2
# action_type Buy less
# base_return 142.2912139892578
# reward 142.2912139892578
# episode_reward 6461.841638183594
# current_step 569
# terminated False
# action_idx 16
# len(self.actions) 7
# stock_idx 2
# action_type_idx 2
# action_type Buy less
# base_return 139.92205810546875
# reward 139.92205810546875
# episode_reward 6601.763696289063
# current_step 570
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 291.9470520019531
# reward 291.9470520019531
# episode_reward 6893.710748291016
# current_step 571
# terminated False
# action_idx 11
# len(self.actions) 7
# stock_idx 1
# action_type_idx 4
# action_type Sell mid
# base_return 157.7845001220703
# reward 78.89225006103516
# episode_reward 6972.602998352051
# current_step 572
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 289.4808044433594
# reward 289.4808044433594
# episode_reward 7262.0838027954105
# current_step 573
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 278.0661926269531
# reward 278.0661926269531
# episode_reward 7540.149995422364
# current_step 574
# terminated True
# Episode 91/100, Total Excess Return: 7540.1500, Epsilon: 0.63
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 266.1684265136719
# reward 266.1684265136719
# episode_reward 266.1684265136719
# current_step 609
# terminated False
# action_idx 14
# len(self.actions) 7
# stock_idx 2
# action_type_idx 0
# action_type Buy more
# base_return 117.06283569335938
# reward 35.11885070800781
# episode_reward 301.2872772216797
# current_step 610
# terminated False
# action_idx 7
# len(self.actions) 7
# stock_idx 1
# action_type_idx 0
# action_type Buy more
# base_return 122.3499984741211
# reward 36.70499954223633
# episode_reward 337.99227676391604
# current_step 611
# terminated False
# action_idx 18
# len(self.actions) 7
# stock_idx 2
# action_type_idx 4
# action_type Sell mid
# base_return 116.2646484375
# reward 58.13232421875
# episode_reward 396.12460098266604
# current_step 612
# terminated False
# action_idx 10
# len(self.actions) 7
# stock_idx 1
# action_type_idx 3
# action_type Sell more
# base_return 123.0
# reward 36.9
# episode_reward 433.024600982666
# current_step 613
# terminated False
# action_idx 8
# len(self.actions) 7
# stock_idx 1
# action_type_idx 1
# action_type Buy mid
# base_return 121.18000030517578
# reward 60.59000015258789
# episode_reward 493.6146011352539
# current_step 614
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 258.71356201171875
# reward 258.71356201171875
# episode_reward 752.3281631469727
# current_step 615
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 247.18434143066406
# reward 247.18434143066406
# episode_reward 999.5125045776367
# current_step 616
# terminated False
# action_idx 14
# len(self.actions) 7
# stock_idx 2
# action_type_idx 0
# action_type Buy more
# base_return 105.88626861572266
# reward 31.765880584716797
# episode_reward 1031.2783851623535
# current_step 617
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 238.87939453125
# reward 238.87939453125
# episode_reward 1270.1577796936035
# current_step 618
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 245.98255920410156
# reward 245.98255920410156
# episode_reward 1516.140338897705
# current_step 619
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 239.348388671875
# reward 239.348388671875
# episode_reward 1755.48872756958
# current_step 620
# terminated False
# action_idx 5
# len(self.actions) 7
# stock_idx 0
# action_type_idx 5
# action_type Sell less
# base_return 129.482666015625
# reward 129.482666015625
# episode_reward 1884.971393585205
# current_step 621
# terminated False
# action_idx 19
# len(self.actions) 7
# stock_idx 2
# action_type_idx 5
# action_type Sell less
# base_return 111.01325225830078
# reward 111.01325225830078
# episode_reward 1995.9846458435059
# current_step 622
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 247.32115173339844
# reward 247.32115173339844
# episode_reward 2243.3057975769043
# current_step 623
# terminated False
# action_idx 5
# len(self.actions) 7
# stock_idx 0
# action_type_idx 5
# action_type Sell less
# base_return 136.0867462158203
# reward 136.0867462158203
# episode_reward 2379.3925437927246
# current_step 624
# terminated False
# action_idx 12
# len(self.actions) 7
# stock_idx 1
# action_type_idx 5
# action_type Sell less
# base_return 116.45999908447266
# reward 116.45999908447266
# episode_reward 2495.8525428771973
# current_step 625
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 258.8112487792969
# reward 258.8112487792969
# episode_reward 2754.663791656494
# current_step 626
# terminated False
# action_idx 2
# len(self.actions) 7
# stock_idx 0
# action_type_idx 2
# action_type Buy less
# base_return 135.2698211669922
# reward 135.2698211669922
# episode_reward 2889.9336128234863
# current_step 627
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 254.28750610351562
# reward 254.28750610351562
# episode_reward 3144.221118927002
# current_step 628
# terminated False
# action_idx 0
# len(self.actions) 7
# stock_idx 0
# action_type_idx 0
# action_type Buy more
# base_return 134.5612335205078
# reward 40.368370056152344
# episode_reward 3184.5894889831543
# current_step 629
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 253.62310791015625
# reward 253.62310791015625
# episode_reward 3438.2125968933105
# current_step 630
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 256.81805419921875
# reward 256.81805419921875
# episode_reward 3695.0306510925293
# current_step 631
# terminated False
# action_idx 18
# len(self.actions) 7
# stock_idx 2
# action_type_idx 4
# action_type Sell mid
# base_return 114.0268325805664
# reward 57.0134162902832
# episode_reward 3752.0440673828125
# current_step 632
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 262.2406921386719
# reward 262.2406921386719
# episode_reward 4014.2847595214844
# current_step 633
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 261.5177001953125
# reward 261.5177001953125
# episode_reward 4275.802459716797
# current_step 634
# terminated False
# action_idx 19
# len(self.actions) 7
# stock_idx 2
# action_type_idx 5
# action_type Sell less
# base_return 115.12609100341797
# reward 115.12609100341797
# episode_reward 4390.928550720215
# current_step 635
# terminated False
# action_idx 21
# len(self.actions) 7
# stock_idx 3
# action_type_idx 0
# action_type Buy more
# base_return 247.84872436523438
# reward 74.35461730957032
# episode_reward 4465.283168029785
# current_step 636
# terminated False
# action_idx 18
# len(self.actions) 7
# stock_idx 2
# action_type_idx 4
# action_type Sell mid
# base_return 110.82364654541016
# reward 55.41182327270508
# episode_reward 4520.69499130249
# current_step 637
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 248.24932861328125
# reward 248.24932861328125
# episode_reward 4768.944319915771
# current_step 638
# terminated False
# action_idx 18
# len(self.actions) 7
# stock_idx 2
# action_type_idx 4
# action_type Sell mid
# base_return 111.24564361572266
# reward 55.62282180786133
# episode_reward 4824.567141723633
# current_step 639
# terminated False
# action_idx 10
# len(self.actions) 7
# stock_idx 1
# action_type_idx 3
# action_type Sell more
# base_return 113.76000213623047
# reward 34.12800064086914
# episode_reward 4858.695142364501
# current_step 640
# terminated False
# action_idx 6
# len(self.actions) 7
# stock_idx 0
# action_type_idx 6
# action_type Keep
# base_return 148.61573791503906
# reward 148.61573791503906
# episode_reward 5007.3108802795405
# current_step 641
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 256.2513427734375
# reward 256.2513427734375
# episode_reward 5263.562223052978
# current_step 642
# terminated False
# action_idx 12
# len(self.actions) 7
# stock_idx 1
# action_type_idx 5
# action_type Sell less
# base_return 124.62999725341797
# reward 124.62999725341797
# episode_reward 5388.192220306396
# current_step 643
# terminated False
# action_idx 8
# len(self.actions) 7
# stock_idx 1
# action_type_idx 1
# action_type Buy mid
# base_return 122.41999816894531
# reward 61.209999084472656
# episode_reward 5449.402219390869
# current_step 644
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 252.8903045654297
# reward 252.8903045654297
# episode_reward 5702.292523956298
# current_step 645
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 246.1193389892578
# reward 246.1193389892578
# episode_reward 5948.411862945556
# current_step 646
# terminated False
# action_idx 3
# len(self.actions) 7
# stock_idx 0
# action_type_idx 3
# action_type Sell more
# base_return 154.3142852783203
# reward 46.29428558349609
# episode_reward 5994.706148529052
# current_step 647
# terminated False
# action_idx 21
# len(self.actions) 7
# stock_idx 3
# action_type_idx 0
# action_type Buy more
# base_return 270.06689453125
# reward 81.020068359375
# episode_reward 6075.726216888427
# current_step 648
# terminated False
# action_idx 26
# len(self.actions) 7
# stock_idx 3
# action_type_idx 5
# action_type Sell less
# base_return 274.2974853515625
# reward 274.2974853515625
# episode_reward 6350.02370223999
# current_step 649
# terminated False
# action_idx 21
# len(self.actions) 7
# stock_idx 3
# action_type_idx 0
# action_type Buy more
# base_return 271.63018798828125
# reward 81.48905639648437
# episode_reward 6431.512758636474
# current_step 650
# terminated False
# action_idx 3
# len(self.actions) 7
# stock_idx 0
# action_type_idx 3
# action_type Sell more
# base_return 157.4834747314453
# reward 47.245042419433595
# episode_reward 6478.757801055908
# current_step 651
# terminated False
# action_idx 22
# len(self.actions) 7
# stock_idx 3
# action_type_idx 1
# action_type Buy mid
# base_return 275.98785400390625
# reward 137.99392700195312
# episode_reward 6616.751728057861
# current_step 652
# terminated False
# action_idx 26
# len(self.actions) 7
# stock_idx 3
# action_type_idx 5
# action_type Sell less
# base_return 277.1407470703125
# reward 277.1407470703125
# episode_reward 6893.892475128174
# current_step 653
# terminated True
# Episode 92/100, Total Excess Return: 6893.8925, Epsilon: 0.63
# action_idx 18
# len(self.actions) 7
# stock_idx 2
# action_type_idx 4
# action_type Sell mid
# base_return 116.0750503540039
# reward 58.03752517700195
# episode_reward 58.03752517700195
# current_step 656
# terminated False
# action_idx 16
# len(self.actions) 7
# stock_idx 2
# action_type_idx 2
# action_type Buy less
# base_return 119.13043975830078
# reward 119.13043975830078
# episode_reward 177.16796493530273
# current_step 657
# terminated False
# action_idx 3
# len(self.actions) 7
# stock_idx 0
# action_type_idx 3
# action_type Sell more
# base_return 166.0598907470703
# reward 49.81796722412109
# episode_reward 226.98593215942384
# current_step 658
# terminated False
# action_idx 26
# len(self.actions) 7
# stock_idx 3
# action_type_idx 5
# action_type Sell less
# base_return 285.2112121582031
# reward 285.2112121582031
# episode_reward 512.1971443176269
# current_step 659
# terminated False
# action_idx 26
# len(self.actions) 7
# stock_idx 3
# action_type_idx 5
# action_type Sell less
# base_return 286.73541259765625
# reward 286.73541259765625
# episode_reward 798.9325569152832
# current_step 660
# terminated False
# action_idx 11
# len(self.actions) 7
# stock_idx 1
# action_type_idx 4
# action_type Sell mid
# base_return 144.77999877929688
# reward 72.38999938964844
# episode_reward 871.3225563049316
# current_step 661
# terminated False
# action_idx 26
# len(self.actions) 7
# stock_idx 3
# action_type_idx 5
# action_type Sell less
# base_return 285.2388916015625
# reward 285.2388916015625
# episode_reward 1156.561447906494
# current_step 662
# terminated False
# action_idx 19
# len(self.actions) 7
# stock_idx 2
# action_type_idx 5
# action_type Sell less
# base_return 119.59819793701172
# reward 119.59819793701172
# episode_reward 1276.1596458435058
# current_step 663
# terminated False
# action_idx 0
# len(self.actions) 7
# stock_idx 0
# action_type_idx 0
# action_type Buy more
# base_return 169.0461883544922
# reward 50.71385650634765
# episode_reward 1326.8735023498534
# current_step 664
# terminated False
# action_idx 8
# len(self.actions) 7
# stock_idx 1
# action_type_idx 1
# action_type Buy mid
# base_return 133.22000122070312
# reward 66.61000061035156
# episode_reward 1393.483502960205
# current_step 665
# terminated False
# action_idx 26
# len(self.actions) 7
# stock_idx 3
# action_type_idx 5
# action_type Sell less
# base_return 270.66949462890625
# reward 270.66949462890625
# episode_reward 1664.1529975891112
# current_step 666
# terminated False
# action_idx 8
# len(self.actions) 7
# stock_idx 1
# action_type_idx 1
# action_type Buy mid
# base_return 133.8000030517578
# reward 66.9000015258789
# episode_reward 1731.0529991149901
# current_step 667
# terminated False
# action_idx 26
# len(self.actions) 7
# stock_idx 3
# action_type_idx 5
# action_type Sell less
# base_return 273.0291442871094
# reward 273.0291442871094
# episode_reward 2004.0821434020995
# current_step 668
# terminated False
# action_idx 13
# len(self.actions) 7
# stock_idx 1
# action_type_idx 6
# action_type Keep
# base_return 130.75
# reward 130.75
# episode_reward 2134.8321434020995
# current_step 669
# terminated False
# action_idx 26
# len(self.actions) 7
# stock_idx 3
# action_type_idx 5
# action_type Sell less
# base_return 259.69354248046875
# reward 259.69354248046875
# episode_reward 2394.5256858825683
# current_step 670
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 257.480712890625
# reward 257.480712890625
# episode_reward 2652.0063987731933
# current_step 671
# terminated False
# action_idx 4
# len(self.actions) 7
# stock_idx 0
# action_type_idx 4
# action_type Sell mid
# base_return 154.9524383544922
# reward 77.4762191772461
# episode_reward 2729.4826179504394
# current_step 672
# terminated False
# action_idx 3
# len(self.actions) 7
# stock_idx 0
# action_type_idx 3
# action_type Sell more
# base_return 155.6817626953125
# reward 46.70452880859375
# episode_reward 2776.187146759033
# current_step 673
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 250.71493530273438
# reward 250.71493530273438
# episode_reward 3026.9020820617675
# current_step 674
# terminated False
# action_idx 15
# len(self.actions) 7
# stock_idx 2
# action_type_idx 1
# action_type Buy mid
# base_return 106.30177307128906
# reward 53.15088653564453
# episode_reward 3080.052968597412
# current_step 675
# terminated False
# action_idx 24
# len(self.actions) 7
# stock_idx 3
# action_type_idx 3
# action_type Sell more
# base_return 252.70254516601562
# reward 75.81076354980469
# episode_reward 3155.8637321472165
# current_step 676
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 253.12355041503906
# reward 253.12355041503906
# episode_reward 3408.9872825622556
# current_step 677
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 258.93963623046875
# reward 258.93963623046875
# episode_reward 3667.9269187927243
# current_step 678
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 261.0838623046875
# reward 261.0838623046875
# episode_reward 3929.010781097412
# current_step 679
# terminated False
# action_idx 2
# len(self.actions) 7
# stock_idx 0
# action_type_idx 2
# action_type Buy less
# base_return 151.6211700439453
# reward 151.6211700439453
# episode_reward 4080.631951141357
# current_step 680
# terminated False
# action_idx 21
# len(self.actions) 7
# stock_idx 3
# action_type_idx 0
# action_type Buy more
# base_return 246.95510864257812
# reward 74.08653259277344
# episode_reward 4154.71848373413
# current_step 681
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 240.25787353515625
# reward 240.25787353515625
# episode_reward 4394.976357269286
# current_step 682
# terminated False
# action_idx 16
# len(self.actions) 7
# stock_idx 2
# action_type_idx 2
# action_type Buy less
# base_return 102.31085968017578
# reward 102.31085968017578
# episode_reward 4497.287216949462
# current_step 683
# terminated False
# action_idx 16
# len(self.actions) 7
# stock_idx 2
# action_type_idx 2
# action_type Buy less
# base_return 102.5795669555664
# reward 102.5795669555664
# episode_reward 4599.866783905029
# current_step 684
# terminated False
# action_idx 26
# len(self.actions) 7
# stock_idx 3
# action_type_idx 5
# action_type Sell less
# base_return 237.3890380859375
# reward 237.3890380859375
# episode_reward 4837.255821990966
# current_step 685
# terminated False
# action_idx 23
# len(self.actions) 7
# stock_idx 3
# action_type_idx 2
# action_type Buy less
# base_return 233.9620819091797
# reward 233.9620819091797
# episode_reward 5071.217903900146
# current_step 686
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 235.94972229003906
# reward 235.94972229003906
# episode_reward 5307.167626190185
# current_step 687
# terminated False
# action_idx 22
# len(self.actions) 7
# stock_idx 3
# action_type_idx 1
# action_type Buy mid
# base_return 232.95358276367188
# reward 116.47679138183594
# episode_reward 5423.644417572021
# current_step 688
# terminated False
# action_idx 8
# len(self.actions) 7
# stock_idx 1
# action_type_idx 1
# action_type Buy mid
# base_return 115.1500015258789
# reward 57.57500076293945
# episode_reward 5481.21941833496
# current_step 689
# terminated False
# action_idx 1
# len(self.actions) 7
# stock_idx 0
# action_type_idx 1
# action_type Buy mid
# base_return 149.57119750976562
# reward 74.78559875488281
# episode_reward 5556.005017089843
# current_step 690
# terminated False
# action_idx 1
# len(self.actions) 7
# stock_idx 0
# action_type_idx 1
# action_type Buy mid
# base_return 147.6788787841797
# reward 73.83943939208984
# episode_reward 5629.844456481933
# current_step 691
# terminated False
# action_idx 0
# len(self.actions) 7
# stock_idx 0
# action_type_idx 0
# action_type Buy more
# base_return 140.42503356933594
# reward 42.12751007080078
# episode_reward 5671.971966552734
# current_step 692
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 228.03839111328125
# reward 228.03839111328125
# episode_reward 5900.010357666015
# current_step 693
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 235.7147216796875
# reward 235.7147216796875
# episode_reward 6135.725079345702
# current_step 694
# terminated False
# action_idx 1
# len(self.actions) 7
# stock_idx 0
# action_type_idx 1
# action_type Buy mid
# base_return 143.99282836914062
# reward 71.99641418457031
# episode_reward 6207.721493530273
# current_step 695
# terminated False
# action_idx 14
# len(self.actions) 7
# stock_idx 2
# action_type_idx 0
# action_type Buy more
# base_return 100.94738006591797
# reward 30.28421401977539
# episode_reward 6238.005707550048
# current_step 696
# terminated False
# action_idx 12
# len(self.actions) 7
# stock_idx 1
# action_type_idx 5
# action_type Sell less
# base_return 120.30000305175781
# reward 120.30000305175781
# episode_reward 6358.305710601806
# current_step 697
# terminated False
# action_idx 1
# len(self.actions) 7
# stock_idx 0
# action_type_idx 1
# action_type Buy mid
# base_return 138.06948852539062
# reward 69.03474426269531
# episode_reward 6427.340454864501
# current_step 698
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 224.46456909179688
# reward 224.46456909179688
# episode_reward 6651.805023956298
# current_step 699
# terminated False
# action_idx 1
# len(self.actions) 7
# stock_idx 0
# action_type_idx 1
# action_type Buy mid
# base_return 136.97549438476562
# reward 68.48774719238281
# episode_reward 6720.292771148681
# current_step 700
# terminated True
# Episode 93/100, Total Excess Return: 6720.2928, Epsilon: 0.63
# action_idx 0
# len(self.actions) 7
# stock_idx 0
# action_type_idx 0
# action_type Buy more
# base_return 187.25868225097656
# reward 56.17760467529297
# episode_reward 56.17760467529297
# current_step 1018
# terminated False
# action_idx 15
# len(self.actions) 7
# stock_idx 2
# action_type_idx 1
# action_type Buy mid
# base_return 145.68350219726562
# reward 72.84175109863281
# episode_reward 129.01935577392578
# current_step 1019
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 392.7794189453125
# reward 392.7794189453125
# episode_reward 521.7987747192383
# current_step 1020
# terminated False
# action_idx 19
# len(self.actions) 7
# stock_idx 2
# action_type_idx 5
# action_type Sell less
# base_return 146.34034729003906
# reward 146.34034729003906
# episode_reward 668.1391220092773
# current_step 1021
# terminated False
# action_idx 15
# len(self.actions) 7
# stock_idx 2
# action_type_idx 1
# action_type Buy mid
# base_return 147.99244689941406
# reward 73.99622344970703
# episode_reward 742.1353454589844
# current_step 1022
# terminated False
# action_idx 11
# len(self.actions) 7
# stock_idx 1
# action_type_idx 4
# action_type Sell mid
# base_return 157.75
# reward 78.875
# episode_reward 821.0103454589844
# current_step 1023
# terminated False
# action_idx 15
# len(self.actions) 7
# stock_idx 2
# action_type_idx 1
# action_type Buy mid
# base_return 151.46585083007812
# reward 75.73292541503906
# episode_reward 896.7432708740234
# current_step 1024
# terminated False
# action_idx 4
# len(self.actions) 7
# stock_idx 0
# action_type_idx 4
# action_type Sell mid
# base_return 190.3361358642578
# reward 95.1680679321289
# episode_reward 991.9113388061523
# current_step 1025
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 404.7457275390625
# reward 404.7457275390625
# episode_reward 1396.6570663452148
# current_step 1026
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 393.83929443359375
# reward 393.83929443359375
# episode_reward 1790.4963607788086
# current_step 1027
# terminated False
# action_idx 2
# len(self.actions) 7
# stock_idx 0
# action_type_idx 2
# action_type Buy less
# base_return 185.5015411376953
# reward 185.5015411376953
# episode_reward 1975.997901916504
# current_step 1028
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 407.3509521484375
# reward 407.3509521484375
# episode_reward 2383.3488540649414
# current_step 1029
# terminated False
# action_idx 14
# len(self.actions) 7
# stock_idx 2
# action_type_idx 0
# action_type Buy more
# base_return 142.99635314941406
# reward 42.898905944824214
# episode_reward 2426.2477600097654
# current_step 1030
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 401.67486572265625
# reward 401.67486572265625
# episode_reward 2827.9226257324217
# current_step 1031
# terminated False
# action_idx 8
# len(self.actions) 7
# stock_idx 1
# action_type_idx 1
# action_type Buy mid
# base_return 170.52999877929688
# reward 85.26499938964844
# episode_reward 2913.18762512207
# current_step 1032
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 410.2137451171875
# reward 410.2137451171875
# episode_reward 3323.4013702392576
# current_step 1033
# terminated False
# action_idx 24
# len(self.actions) 7
# stock_idx 3
# action_type_idx 3
# action_type Sell more
# base_return 416.5931701660156
# reward 124.97795104980469
# episode_reward 3448.3793212890623
# current_step 1034
# terminated False
# action_idx 21
# len(self.actions) 7
# stock_idx 3
# action_type_idx 0
# action_type Buy more
# base_return 411.35296630859375
# reward 123.40588989257812
# episode_reward 3571.7852111816405
# current_step 1035
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 402.4970703125
# reward 402.4970703125
# episode_reward 3974.2822814941405
# current_step 1036
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 406.3873291015625
# reward 406.3873291015625
# episode_reward 4380.6696105957035
# current_step 1037
# terminated False
# action_idx 6
# len(self.actions) 7
# stock_idx 0
# action_type_idx 6
# action_type Keep
# base_return 182.7562713623047
# reward 182.7562713623047
# episode_reward 4563.425881958008
# current_step 1038
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 400.99853515625
# reward 400.99853515625
# episode_reward 4964.424417114258
# current_step 1039
# terminated False
# action_idx 16
# len(self.actions) 7
# stock_idx 2
# action_type_idx 2
# action_type Buy less
# base_return 140.44851684570312
# reward 140.44851684570312
# episode_reward 5104.872933959961
# current_step 1040
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 399.13275146484375
# reward 399.13275146484375
# episode_reward 5504.005685424805
# current_step 1041
# terminated False
# action_idx 15
# len(self.actions) 7
# stock_idx 2
# action_type_idx 1
# action_type Buy mid
# base_return 143.40438842773438
# reward 71.70219421386719
# episode_reward 5575.707879638672
# current_step 1042
# terminated False
# action_idx 17
# len(self.actions) 7
# stock_idx 2
# action_type_idx 3
# action_type Sell more
# base_return 143.2750244140625
# reward 42.98250732421875
# episode_reward 5618.690386962891
# current_step 1043
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 404.4521484375
# reward 404.4521484375
# episode_reward 6023.142535400391
# current_step 1044
# terminated False
# action_idx 10
# len(self.actions) 7
# stock_idx 1
# action_type_idx 3
# action_type Sell more
# base_return 173.5399932861328
# reward 52.061997985839845
# episode_reward 6075.204533386232
# current_step 1045
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 404.63079833984375
# reward 404.63079833984375
# episode_reward 6479.835331726075
# current_step 1046
# terminated False
# action_idx 2
# len(self.actions) 7
# stock_idx 0
# action_type_idx 2
# action_type Buy less
# base_return 179.66493225097656
# reward 179.66493225097656
# episode_reward 6659.500263977052
# current_step 1047
# terminated False
# action_idx 7
# len(self.actions) 7
# stock_idx 1
# action_type_idx 0
# action_type Buy more
# base_return 178.22000122070312
# reward 53.466000366210935
# episode_reward 6712.966264343263
# current_step 1048
# terminated False
# action_idx 4
# len(self.actions) 7
# stock_idx 0
# action_type_idx 4
# action_type Sell mid
# base_return 174.04884338378906
# reward 87.02442169189453
# episode_reward 6799.9906860351575
# current_step 1049
# terminated False
# action_idx 13
# len(self.actions) 7
# stock_idx 1
# action_type_idx 6
# action_type Keep
# base_return 174.1199951171875
# reward 174.1199951171875
# episode_reward 6974.110681152345
# current_step 1050
# terminated False
# action_idx 8
# len(self.actions) 7
# stock_idx 1
# action_type_idx 1
# action_type Buy mid
# base_return 173.50999450683594
# reward 86.75499725341797
# episode_reward 7060.865678405763
# current_step 1051
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 406.0400390625
# reward 406.0400390625
# episode_reward 7466.905717468263
# current_step 1052
# terminated False
# action_idx 1
# len(self.actions) 7
# stock_idx 0
# action_type_idx 1
# action_type Buy mid
# base_return 169.70509338378906
# reward 84.85254669189453
# episode_reward 7551.7582641601575
# current_step 1053
# terminated False
# action_idx 2
# len(self.actions) 7
# stock_idx 0
# action_type_idx 2
# action_type Buy less
# base_return 171.71295166015625
# reward 171.71295166015625
# episode_reward 7723.471215820314
# current_step 1054
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 412.13348388671875
# reward 412.13348388671875
# episode_reward 8135.6046997070325
# current_step 1055
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 411.95489501953125
# reward 411.95489501953125
# episode_reward 8547.559594726565
# current_step 1056
# terminated False
# action_idx 8
# len(self.actions) 7
# stock_idx 1
# action_type_idx 1
# action_type Buy mid
# base_return 178.75
# reward 89.375
# episode_reward 8636.934594726565
# current_step 1057
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 413.264892578125
# reward 413.264892578125
# episode_reward 9050.19948730469
# current_step 1058
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 414.1580505371094
# reward 414.1580505371094
# episode_reward 9464.357537841799
# current_step 1059
# terminated False
# action_idx 2
# len(self.actions) 7
# stock_idx 0
# action_type_idx 2
# action_type Buy less
# base_return 175.02296447753906
# reward 175.02296447753906
# episode_reward 9639.380502319338
# current_step 1060
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 422.00811767578125
# reward 422.00811767578125
# episode_reward 10061.38861999512
# current_step 1061
# terminated False
# action_idx 2
# len(self.actions) 7
# stock_idx 0
# action_type_idx 2
# action_type Buy less
# base_return 170.3412322998047
# reward 170.3412322998047
# episode_reward 10231.729852294924
# current_step 1062
# terminated True
# Episode 94/100, Total Excess Return: 10231.7299, Epsilon: 0.62
# action_idx 10
# len(self.actions) 7
# stock_idx 1
# action_type_idx 3
# action_type Sell more
# base_return 139.98599243164062
# reward 41.99579772949219
# episode_reward 41.99579772949219
# current_step 521
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 288.6305847167969
# reward 288.6305847167969
# ...
# action_type_idx 0
# action_type Buy more
# base_return 178.5719451904297
# reward 53.5715835571289
# episode_reward 2988.004261779786
# current_step 1126
# terminated False
# action_idx 23
# len(self.actions) 7
# stock_idx 3
# action_type_idx 2
# action_type Buy less
# base_return 448.3404541015625
# reward 448.3404541015625
# episode_reward 3436.3447158813483
# current_step 1127
# terminated False
# action_idx 23
# len(self.actions) 7
# stock_idx 3
# action_type_idx 2
# action_type Buy less
# base_return 449.54345703125
# reward 449.54345703125
# episode_reward 3885.8881729125983
# current_step 1128
# terminated False
# action_idx 18
# len(self.actions) 7
# stock_idx 2
# action_type_idx 4
# action_type Sell mid
# base_return 184.73956298828125
# reward 92.36978149414062
# episode_reward 3978.257954406739
# current_step 1129
# terminated False
# action_idx 23
# len(self.actions) 7
# stock_idx 3
# action_type_idx 2
# action_type Buy less
# base_return 444.3636169433594
# reward 444.3636169433594
# episode_reward 4422.621571350099
# current_step 1130
# terminated False
# action_idx 21
# len(self.actions) 7
# stock_idx 3
# action_type_idx 0
# action_type Buy more
# base_return 454.0870056152344
# reward 136.2261016845703
# episode_reward 4558.847673034669
# current_step 1131
# terminated False
# action_idx 13
# len(self.actions) 7
# stock_idx 1
# action_type_idx 6
# action_type Keep
# base_return 200.0
# reward 200.0
# episode_reward 4758.847673034669
# current_step 1132
# terminated False
# action_idx 1
# len(self.actions) 7
# stock_idx 0
# action_type_idx 1
# action_type Buy mid
# base_return 220.51870727539062
# reward 110.25935363769531
# episode_reward 4869.107026672365
# current_step 1133
# terminated False
# action_idx 23
# len(self.actions) 7
# stock_idx 3
# action_type_idx 2
# action_type Buy less
# base_return 464.8543395996094
# reward 464.8543395996094
# episode_reward 5333.961366271974
# current_step 1134
# terminated False
# action_idx 23
# len(self.actions) 7
# stock_idx 3
# action_type_idx 2
# action_type Buy less
# base_return 463.5419921875
# reward 463.5419921875
# episode_reward 5797.503358459474
# current_step 1135
# terminated False
# action_idx 18
# len(self.actions) 7
# stock_idx 2
# action_type_idx 4
# action_type Sell mid
# base_return 188.29666137695312
# reward 94.14833068847656
# episode_reward 5891.6516891479505
# current_step 1136
# terminated False
# action_idx 23
# len(self.actions) 7
# stock_idx 3
# action_type_idx 2
# action_type Buy less
# base_return 463.55194091796875
# reward 463.55194091796875
# episode_reward 6355.203630065919
# current_step 1137
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 452.06878662109375
# reward 452.06878662109375
# episode_reward 6807.272416687013
# current_step 1138
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 450.9254150390625
# reward 450.9254150390625
# episode_reward 7258.1978317260755
# current_step 1139
# terminated False
# action_idx 2
# len(self.actions) 7
# stock_idx 0
# action_type_idx 2
# action_type Buy less
# base_return 233.3088836669922
# reward 233.3088836669922
# episode_reward 7491.506715393068
# current_step 1140
# terminated False
# action_idx 8
# len(self.actions) 7
# stock_idx 1
# action_type_idx 1
# action_type Buy mid
# base_return 193.02000427246094
# reward 96.51000213623047
# episode_reward 7588.016717529298
# current_step 1141
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 440.9534606933594
# reward 440.9534606933594
# episode_reward 8028.9701782226575
# current_step 1142
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 437.8216857910156
# reward 437.8216857910156
# episode_reward 8466.791864013674
# current_step 1143
# terminated False
# action_idx 18
# len(self.actions) 7
# stock_idx 2
# action_type_idx 4
# action_type Sell mid
# base_return 177.01759338378906
# reward 88.50879669189453
# episode_reward 8555.300660705569
# current_step 1144
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 440.3768310546875
# reward 440.3768310546875
# episode_reward 8995.677491760256
# current_step 1145
# terminated False
# action_idx 9
# len(self.actions) 7
# stock_idx 1
# action_type_idx 2
# action_type Buy less
# base_return 186.41000366210938
# reward 186.41000366210938
# episode_reward 9182.087495422365
# current_step 1146
# terminated False
# action_idx 21
# len(self.actions) 7
# stock_idx 3
# action_type_idx 0
# action_type Buy more
# base_return 426.4180603027344
# reward 127.9254180908203
# episode_reward 9310.012913513187
# current_step 1147
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 415.97882080078125
# reward 415.97882080078125
# episode_reward 9725.991734313968
# current_step 1148
# terminated False
# action_idx 14
# len(self.actions) 7
# stock_idx 2
# action_type_idx 0
# action_type Buy more
# base_return 166.3961181640625
# reward 49.91883544921875
# episode_reward 9775.910569763186
# current_step 1149
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 424.2606506347656
# reward 424.2606506347656
# episode_reward 10200.171220397951
# current_step 1150
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 420.4726867675781
# reward 420.4726867675781
# episode_reward 10620.64390716553
# current_step 1151
# terminated False
# action_idx 1
# len(self.actions) 7
# stock_idx 0
# action_type_idx 1
# action_type Buy mid
# base_return 221.04623413085938
# reward 110.52311706542969
# episode_reward 10731.16702423096
# current_step 1152
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 414.6962585449219
# reward 414.6962585449219
# episode_reward 11145.863282775881
# current_step 1153
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 406.12615966796875
# reward 406.12615966796875
# episode_reward 11551.98944244385
# current_step 1154
# terminated False
# action_idx 25
# len(self.actions) 7
# stock_idx 3
# action_type_idx 4
# action_type Sell mid
# base_return 392.8633728027344
# reward 196.4316864013672
# episode_reward 11748.421128845217
# current_step 1155
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 397.29754638671875
# reward 397.29754638671875
# episode_reward 12145.718675231936
# current_step 1156
# terminated False
# action_idx 20
# len(self.actions) 7
# stock_idx 2
# action_type_idx 6
# action_type Keep
# base_return 158.36526489257812
# reward 158.36526489257812
# episode_reward 12304.083940124514
# current_step 1157
# terminated True
# Episode 99/100, Total Excess Return: 12304.0839, Epsilon: 0.61
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 404.4521484375
# reward 404.4521484375
# episode_reward 404.4521484375
# current_step 1044
# terminated False
# action_idx 17
# len(self.actions) 7
# stock_idx 2
# action_type_idx 3
# action_type Sell more
# base_return 138.2191925048828
# reward 41.46575775146484
# episode_reward 445.9179061889648
# current_step 1045
# terminated False
# action_idx 8
# len(self.actions) 7
# stock_idx 1
# action_type_idx 1
# action_type Buy mid
# base_return 173.16000366210938
# reward 86.58000183105469
# episode_reward 532.4979080200195
# current_step 1046
# terminated False
# action_idx 24
# len(self.actions) 7
# stock_idx 3
# action_type_idx 3
# action_type Sell more
# base_return 410.5059509277344
# reward 123.1517852783203
# episode_reward 655.6496932983398
# current_step 1047
# terminated False
# action_idx 12
# len(self.actions) 7
# stock_idx 1
# action_type_idx 5
# action_type Sell less
# base_return 178.22000122070312
# reward 178.22000122070312
# episode_reward 833.8696945190429
# current_step 1048
# terminated False
# action_idx 0
# len(self.actions) 7
# stock_idx 0
# action_type_idx 0
# action_type Buy more
# base_return 174.04884338378906
# reward 52.21465301513672
# episode_reward 886.0843475341796
# current_step 1049
# terminated False
# action_idx 8
# len(self.actions) 7
# stock_idx 1
# action_type_idx 1
# action_type Buy mid
# base_return 174.1199951171875
# reward 87.05999755859375
# episode_reward 973.1443450927734
# current_step 1050
# terminated False
# action_idx 8
# len(self.actions) 7
# stock_idx 1
# action_type_idx 1
# action_type Buy mid
# base_return 173.50999450683594
# reward 86.75499725341797
# episode_reward 1059.8993423461914
# current_step 1051
# terminated False
# action_idx 26
# len(self.actions) 7
# stock_idx 3
# action_type_idx 5
# action_type Sell less
# base_return 406.0400390625
# reward 406.0400390625
# episode_reward 1465.9393814086914
# current_step 1052
# terminated False
# action_idx 19
# len(self.actions) 7
# stock_idx 2
# action_type_idx 5
# action_type Sell less
# base_return 134.7657012939453
# reward 134.7657012939453
# episode_reward 1600.7050827026367
# current_step 1053
# terminated False
# action_idx 10
# len(self.actions) 7
# stock_idx 1
# action_type_idx 3
# action_type Sell more
# base_return 171.9600067138672
# reward 51.58800201416015
# episode_reward 1652.2930847167968
# current_step 1054
# terminated False
# action_idx 26
# len(self.actions) 7
# stock_idx 3
# action_type_idx 5
# action_type Sell less
# base_return 412.13348388671875
# reward 412.13348388671875
# episode_reward 2064.4265686035155
# current_step 1055
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 411.95489501953125
# reward 411.95489501953125
# episode_reward 2476.381463623047
# current_step 1056
# terminated False
# action_idx 26
# len(self.actions) 7
# stock_idx 3
# action_type_idx 5
# action_type Sell less
# base_return 421.9981994628906
# reward 421.9981994628906
# episode_reward 2898.3796630859374
# current_step 1057
# terminated False
# action_idx 18
# len(self.actions) 7
# stock_idx 2
# action_type_idx 4
# action_type Sell mid
# base_return 140.50823974609375
# reward 70.25411987304688
# episode_reward 2968.6337829589843
# current_step 1058
# terminated False
# action_idx 13
# len(self.actions) 7
# stock_idx 1
# action_type_idx 6
# action_type Keep
# base_return 174.47999572753906
# reward 174.47999572753906
# episode_reward 3143.1137786865233
# current_step 1059
# terminated False
# action_idx 6
# len(self.actions) 7
# stock_idx 0
# action_type_idx 6
# action_type Keep
# base_return 175.02296447753906
# reward 175.02296447753906
# episode_reward 3318.1367431640624
# current_step 1060
# terminated False
# action_idx 16
# len(self.actions) 7
# stock_idx 2
# action_type_idx 2
# action_type Buy less
# base_return 148.03225708007812
# reward 148.03225708007812
# episode_reward 3466.1690002441405
# current_step 1061
# terminated False
# action_idx 26
# len(self.actions) 7
# stock_idx 3
# action_type_idx 5
# action_type Sell less
# base_return 426.1167297363281
# reward 426.1167297363281
# episode_reward 3892.2857299804687
# current_step 1062
# terminated False
# action_idx 26
# len(self.actions) 7
# stock_idx 3
# action_type_idx 5
# action_type Sell less
# base_return 425.4915466308594
# reward 425.4915466308594
# episode_reward 4317.7772766113285
# current_step 1063
# terminated False
# action_idx 26
# len(self.actions) 7
# stock_idx 3
# action_type_idx 5
# action_type Sell less
# base_return 419.65606689453125
# reward 419.65606689453125
# episode_reward 4737.43334350586
# current_step 1064
# terminated False
# action_idx 18
# len(self.actions) 7
# stock_idx 2
# action_type_idx 4
# action_type Sell mid
# base_return 149.9530792236328
# reward 74.9765396118164
# episode_reward 4812.409883117676
# current_step 1065
# terminated False
# action_idx 13
# len(self.actions) 7
# stock_idx 1
# action_type_idx 6
# action_type Keep
# base_return 179.8300018310547
# reward 179.8300018310547
# episode_reward 4992.239884948731
# current_step 1066
# terminated False
# action_idx 25
# len(self.actions) 7
# stock_idx 3
# action_type_idx 4
# action_type Sell mid
# base_return 417.53228759765625
# reward 208.76614379882812
# episode_reward 5201.006028747559
# current_step 1067
# terminated False
# action_idx 0
# len(self.actions) 7
# stock_idx 0
# action_type_idx 0
# action_type Buy more
# base_return 169.00927734375
# reward 50.702783203125
# episode_reward 5251.708811950684
# current_step 1068
# terminated False
# action_idx 26
# len(self.actions) 7
# stock_idx 3
# action_type_idx 5
# action_type Sell less
# base_return 418.2468566894531
# reward 418.2468566894531
# episode_reward 5669.955668640137
# current_step 1069
# terminated False
# action_idx 24
# len(self.actions) 7
# stock_idx 3
# action_type_idx 3
# action_type Sell more
# base_return 417.26434326171875
# reward 125.17930297851562
# episode_reward 5795.134971618653
# current_step 1070
# terminated False
# action_idx 8
# len(self.actions) 7
# stock_idx 1
# action_type_idx 1
# action_type Buy mid
# base_return 180.0
# reward 90.0
# episode_reward 5885.134971618653
# current_step 1071
# terminated False
# action_idx 26
# len(self.actions) 7
# stock_idx 3
# action_type_idx 5
# action_type Sell less
# base_return 422.2958984375
# reward 422.2958984375
# episode_reward 6307.430870056153
# current_step 1072
# terminated False
# action_idx 26
# len(self.actions) 7
# stock_idx 3
# action_type_idx 5
# action_type Sell less
# base_return 421.3729553222656
# reward 421.3729553222656
# episode_reward 6728.803825378419
# current_step 1073
# terminated False
# action_idx 26
# len(self.actions) 7
# stock_idx 3
# action_type_idx 5
# action_type Sell less
# base_return 423.0501708984375
# reward 423.0501708984375
# episode_reward 7151.853996276856
# current_step 1074
# terminated False
# action_idx 19
# len(self.actions) 7
# stock_idx 2
# action_type_idx 5
# action_type Sell less
# base_return 155.39706420898438
# reward 155.39706420898438
# episode_reward 7307.251060485841
# current_step 1075
# terminated False
# action_idx 15
# len(self.actions) 7
# stock_idx 2
# action_type_idx 1
# action_type Buy mid
# base_return 158.65151977539062
# reward 79.32575988769531
# episode_reward 7386.576820373536
# current_step 1076
# terminated False
# action_idx 24
# len(self.actions) 7
# stock_idx 3
# action_type_idx 3
# action_type Sell more
# base_return 418.703369140625
# reward 125.61101074218749
# episode_reward 7512.187831115723
# current_step 1077
# terminated False
# action_idx 26
# len(self.actions) 7
# stock_idx 3
# action_type_idx 5
# action_type Sell less
# base_return 410.5059509277344
# reward 410.5059509277344
# episode_reward 7922.693782043458
# current_step 1078
# terminated False
# action_idx 1
# len(self.actions) 7
# stock_idx 0
# action_type_idx 1
# action_type Buy mid
# base_return 168.36317443847656
# reward 84.18158721923828
# episode_reward 8006.875369262696
# current_step 1079
# terminated False
# action_idx 3
# len(self.actions) 7
# stock_idx 0
# action_type_idx 3
# action_type Sell more
# base_return 166.991455078125
# reward 50.0974365234375
# episode_reward 8056.972805786134
# current_step 1080
# terminated False
# action_idx 26
# len(self.actions) 7
# stock_idx 3
# action_type_idx 5
# action_type Sell less
# base_return 401.2069091796875
# reward 401.2069091796875
# episode_reward 8458.179714965821
# current_step 1081
# terminated False
# action_idx 22
# len(self.actions) 7
# stock_idx 3
# action_type_idx 1
# action_type Buy mid
# base_return 396.095947265625
# reward 198.0479736328125
# episode_reward 8656.227688598634
# current_step 1082
# terminated False
# action_idx 12
# len(self.actions) 7
# stock_idx 1
# action_type_idx 5
# action_type Sell less
# base_return 177.22999572753906
# reward 177.22999572753906
# episode_reward 8833.457684326173
# current_step 1083
# terminated False
# action_idx 0
# len(self.actions) 7
# stock_idx 0
# action_type_idx 0
# action_type Buy more
# base_return 165.89805603027344
# reward 49.76941680908203
# episode_reward 8883.227101135255
# current_step 1084
# terminated False
# action_idx 14
# len(self.actions) 7
# stock_idx 2
# action_type_idx 0
# action_type Buy more
# base_return 158.3728485107422
# reward 47.511854553222655
# episode_reward 8930.738955688477
# current_step 1085
# terminated False
# action_idx 23
# len(self.actions) 7
# stock_idx 3
# action_type_idx 2
# action_type Buy less
# base_return 396.0165710449219
# reward 396.0165710449219
# episode_reward 9326.7555267334
# current_step 1086
# terminated False
# action_idx 16
# len(self.actions) 7
# stock_idx 2
# action_type_idx 2
# action_type Buy less
# base_return 171.1318359375
# reward 171.1318359375
# episode_reward 9497.8873626709
# current_step 1087
# terminated False
# action_idx 17
# len(self.actions) 7
# stock_idx 2
# action_type_idx 3
# action_type Sell more
# base_return 165.3594207763672
# reward 49.607826232910156
# episode_reward 9547.49518890381
# current_step 1088
# terminated True
# Episode 100/100, Total Excess Return: 9547.4952, Epsilon: 0.61

# %%
def load_stock_data(tickers, start="2020-01-01", end="2024-12-31"):
    data = yf.download(tickers, start=start, end=end)["Close"]
    #returns = data.pct_change().dropna()
    return data

returns_df = load_stock_data(stocks)
returns_df.head()
# Out:
# [*********************100%***********************]  4 of 4 completed
# Ticker           AAPL       AMZN      GOOGL        MSFT
# Date
# 2020-01-02  72.620834  94.900497  68.108376  153.323288
# 2020-01-03  71.914803  93.748497  67.752083  151.414108
# 2020-01-06  72.487846  95.143997  69.557945  151.805511
# 2020-01-07  72.146942  95.343002  69.423592  150.421387
# 2020-01-08  73.307510  94.598503  69.917725  152.817307

# %%
def run_inference(env, model):
    model.eval()  # set model to evaluation mode
    state, _ = env.reset()
    state = torch.FloatTensor(state).unsqueeze(0).to(device)
    total_reward = 0
    actions_taken = []

    with torch.no_grad():
        for t in range(env.window_size):
            q_values = model(state)
            action = q_values.argmax().item()
            actions_taken.append(action)

            next_state, reward, terminated, truncated, _ = env.step(action)
            total_reward += reward
            done = terminated or truncated
            if done:
                break

            state = torch.FloatTensor(next_state).unsqueeze(0).to(device)

    print(f"Inference run completed. Total reward: {total_reward:.4f}")
    print("Actions taken:", actions_taken)

    stock_idx = action // len(actions)
    action_type = actions[action % len(actions)]
    print(f"Day {t}: {stocks[stock_idx]} - {action_type}")

# %%
run_inference(env, model)
# Out:
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 325.80010986328125
# reward 325.80010986328125
# episode_reward 325.80010986328125
# current_step 488
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 325.8487854003906
# reward 325.8487854003906
# episode_reward 651.6488952636719
# current_step 489
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 324.0297546386719
# reward 324.0297546386719
# episode_reward 975.6786499023438
# current_step 490
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 333.2126770019531
# reward 333.2126770019531
# episode_reward 1308.8913269042969
# current_step 491
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 330.15814208984375
# reward 330.15814208984375
# episode_reward 1639.0494689941406
# current_step 492
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 319.3993225097656
# reward 319.3993225097656
# episode_reward 1958.4487915039062
# current_step 493
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 325.53753662109375
# reward 325.53753662109375
# episode_reward 2283.986328125
# current_step 494
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 316.0530090332031
# reward 316.0530090332031
# episode_reward 2600.039337158203
# current_step 495
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 314.98297119140625
# reward 314.98297119140625
# episode_reward 2915.0223083496094
# current_step 496
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 311.1988830566406
# reward 311.1988830566406
# episode_reward 3226.22119140625
# current_step 497
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 318.3779296875
# reward 318.3779296875
# episode_reward 3544.59912109375
# current_step 498
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 324.1270446777344
# reward 324.1270446777344
# episode_reward 3868.7261657714844
# current_step 499
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 325.57647705078125
# reward 325.57647705078125
# episode_reward 4194.302642822266
# current_step 500
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 333.1251220703125
# reward 333.1251220703125
# episode_reward 4527.427764892578
# current_step 501
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 331.9577941894531
# reward 331.9577941894531
# episode_reward 4859.385559082031
# current_step 502
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 332.6388244628906
# reward 332.6388244628906
# episode_reward 5192.024383544922
# current_step 503
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 330.0803527832031
# reward 330.0803527832031
# episode_reward 5522.104736328125
# current_step 504
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 327.16204833984375
# reward 327.16204833984375
# episode_reward 5849.266784667969
# current_step 505
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 325.6347351074219
# reward 325.6347351074219
# episode_reward 6174.901519775391
# current_step 506
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 320.0510559082031
# reward 320.0510559082031
# episode_reward 6494.952575683594
# current_step 507
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 307.7650146484375
# reward 307.7650146484375
# episode_reward 6802.717590332031
# current_step 508
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 305.33306884765625
# reward 305.33306884765625
# episode_reward 7108.0506591796875
# current_step 509
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 305.4887390136719
# reward 305.4887390136719
# episode_reward 7413.539398193359
# current_step 510
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 305.7124328613281
# reward 305.7124328613281
# episode_reward 7719.2518310546875
# current_step 511
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 306.4031677246094
# reward 306.4031677246094
# episode_reward 8025.654998779297
# current_step 512
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 309.60357666015625
# reward 309.60357666015625
# episode_reward 8335.258575439453
# current_step 513
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 296.5003356933594
# reward 296.5003356933594
# episode_reward 8631.758911132812
# current_step 514
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 301.7532958984375
# reward 301.7532958984375
# episode_reward 8933.51220703125
# current_step 515
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 294.4089050292969
# reward 294.4089050292969
# episode_reward 9227.921112060547
# current_step 516
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 295.0703125
# reward 295.0703125
# episode_reward 9522.991424560547
# current_step 517
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 293.3874206542969
# reward 293.3874206542969
# episode_reward 9816.378845214844
# current_step 518
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 287.9690856933594
# reward 287.9690856933594
# episode_reward 10104.347930908203
# current_step 519
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 288.2998352050781
# reward 288.2998352050781
# episode_reward 10392.647766113281
# current_step 520
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 280.63446044921875
# reward 280.63446044921875
# episode_reward 10673.2822265625
# current_step 521
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 288.6305847167969
# reward 288.6305847167969
# episode_reward 10961.912811279297
# current_step 522
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 291.67535400390625
# reward 291.67535400390625
# episode_reward 11253.588165283203
# current_step 523
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 299.8660888671875
# reward 299.8660888671875
# episode_reward 11553.45425415039
# current_step 524
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 302.5120849609375
# reward 302.5120849609375
# episode_reward 11855.966339111328
# current_step 525
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 300.3525085449219
# reward 300.3525085449219
# episode_reward 12156.31884765625
# current_step 526
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 304.92449951171875
# reward 304.92449951171875
# episode_reward 12461.243347167969
# current_step 527
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 293.04693603515625
# reward 293.04693603515625
# episode_reward 12754.290283203125
# current_step 528
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 297.6093444824219
# reward 297.6093444824219
# episode_reward 13051.899627685547
# current_step 529
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 292.755126953125
# reward 292.755126953125
# episode_reward 13344.654754638672
# current_step 530
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 296.266845703125
# reward 296.266845703125
# episode_reward 13640.921600341797
# current_step 531
# terminated False
# action_idx 27
# len(self.actions) 7
# stock_idx 3
# action_type_idx 6
# action_type Keep
# base_return 302.7357482910156
# reward 302.7357482910156
# episode_reward 13943.657348632812
# current_step 532
# terminated True
# Inference run completed. Total reward: 13943.6573
# Actions taken: [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Day 44: AMZN - Keep
